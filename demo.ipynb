# %% [markdown]
# # Set Up Code

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
os.getcwd()
# Out:
# '/Users/austinclime/VS code projects/spoofing_orders_crypto'

# %% [markdown]
# tardis_dev.datasets.download() internally uses asyncio.run(), which cannot be called from within an already running event loop — a common issue when running code inside Jupyter notebooks, IPython, or some async frameworks
#
# Solution: add the code below at the top of the notebook

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# importing basic packages and helper functions

# %%
import pandas as pd
from tardis_test import sample_query

# %% [markdown]
# # Sample Tardis Query

# %%
start_date = "2019-11-01"
end_date = "2019-11-02" # non inclusive
sample = sample_query(start_date,end_date)

# %%
# NOTE: Tardis data files can be large can occupy a lot of memory
file_path="datasets/deribit_book_snapshot_25_2019-11-01_BTC-PERPETUAL.csv.gz"
df = pd.read_csv(file_path, compression='gzip',nrows=10_000)

# %%
display(df)
# Out:
#      exchange         symbol         timestamp   local_timestamp  \
# 0     deribit  BTC-PERPETUAL  1572566400260000  1572566400497845
# 1     deribit  BTC-PERPETUAL  1572566400450000  1572566400510049
# 2     deribit  BTC-PERPETUAL  1572566400674000  1572566400693767
# 3     deribit  BTC-PERPETUAL  1572566400846000  1572566400860327
# 4     deribit  BTC-PERPETUAL  1572566400865000  1572566400882255
# ...       ...            ...               ...               ...
# 9995  deribit  BTC-PERPETUAL  1572566535280000  1572566535289441
# 9996  deribit  BTC-PERPETUAL  1572566535281000  1572566535290676
# 9997  deribit  BTC-PERPETUAL  1572566535287000  1572566535296450
# 9998  deribit  BTC-PERPETUAL  1572566535305000  1572566535314111
# 9999  deribit  BTC-PERPETUAL  1572566535307000  1572566535317922
#
#       asks[0].price  asks[0].amount  bids[0].price  bids[0].amount  \
# 0            9158.0           53250         9157.5           35920
# ...

# %%
import dask.dataframe as dd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import dask.dataframe as dd
#
# ModuleNotFoundError: No module named 'dask'

# %%
import time
file_path="datasets/deribit_book_snapshot_25_2019-11-01_BTC-PERPETUAL.csv.gz"
start_time = time.time()
df = pd.read_csv(file_path, compression='gzip')
print(f"\nTotal elapsed time: {time.time() - start_time:.2f} seconds")
